# %% [markdown]
# # Sanity Checks
#
# Use this notebook only for lightweight checks. Core pipeline logic lives in `src/`.

# %%
from pathlib import Path

for path in [
    Path('../configs/common.yaml'),
    Path('../configs/datasets.yaml'),
    Path('../src/common/data_io.py'),
    Path('../src/models/run_random_forest.py'),
]:
    print(path, path.exists())

# %%
# After filling configs/datasets.yaml with a real dataset, run experiments from the terminal:
# python -m src.models.run_random_forest --dataset DATASET_NAME --seed 42
# python -m src.common.aggregate_results --input results/raw --output results/summary/results.csv
